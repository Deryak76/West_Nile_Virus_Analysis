# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
import pandas.core.algorithms as algos
from pandas import Series
import scipy.stats.stats as stats
import re
import traceback
import string
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# # General Information about Data Sets

# %%
train2= pd.read_csv('cleaned_train.csv')
weather= pd.read_csv('cleaned_weather.csv')
spray2= pd.read_csv('cleaned_spray.csv')
train= train2.drop(['Year','Month','Day'], axis=1)
spray= spray2.drop(['Year','YearMonth','Day','YearWeek','Month'], axis=1)
train['Date']=pd.to_datetime(train['Date'])
spray['Date']=pd.to_datetime(spray['Date'])
weather['Date']=pd.to_datetime(weather['Date'])
weather['YearWeek']= (weather['Year'].astype(str)+weather['Week'].astype(str)).astype('int64')
weather['YearMonth']=(weather['Year'].astype(str)+weather['Month'].astype(str)).astype('int64')
weather.drop(['Week','Day'], axis=1, inplace=True)

# %%
print(train.info(),weather.info(),spray.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9693 entries, 0 to 9692
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          9693 non-null   datetime64[ns]
#  1   Species       9693 non-null   object
#  2   Latitude      9693 non-null   float64
#  3   Longitude     9693 non-null   float64
#  4   NumMosquitos  9693 non-null   int64
#  5   WnvPresent    9693 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(1)
# memory usage: 454.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         1472 non-null   datetime64[ns]
#  1   Tmax         1472 non-null   int64
#  2   Tmin         1472 non-null   int64
#  3   Tavg         1472 non-null   int64
#  4   Depart       1472 non-null   float64
#  5   DewPoint     1472 non-null   float64
#  6   WetBulb      1472 non-null   float64
#  7   Heat         1472 non-null   float64
#  8   Cool         1472 non-null   float64
#  9   PrecipTotal  1472 non-null   float64
#  10  StnPressure  1472 non-null   float64
#  11  SeaLevel     1472 non-null   float64
#  12  ResultSpeed  1472 non-null   float64
#  13  ResultDir    1472 non-null   float64
#  14  AvgSpeed     1472 non-null   float64
#  15  Year         1472 non-null   int64
#  16  Month        1472 non-null   int64
#  17  YearWeek     1472 non-null   int64
#  18  YearMonth    1472 non-null   int64
# dtypes: datetime64[ns](1), float64(11), int64(7)
# memory usage: 218.6 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14294 entries, 0 to 14293
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       14294 non-null  datetime64[ns]
#  1   Latitude   14294 non-null  float64
#  2   Longitude  14294 non-null  float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 335.1 KB
# None None None

# %%
weather.head()
# Out:
#         Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  Cool  \
# 0 2007-05-01    83    51    67    14.0      51.0     56.5   0.0   2.5
# 1 2007-05-02    59    42    51    -3.0      42.0     47.0  13.5   0.0
# 2 2007-05-03    66    47    57     2.0      40.0     49.0   8.0   0.0
# 3 2007-05-04    72    50    61     4.0      41.5     50.0   4.0   0.0
# 4 2007-05-05    66    53    60     5.0      38.5     49.5   5.0   0.0
#
#    PrecipTotal  StnPressure  SeaLevel  ResultSpeed  ResultDir  AvgSpeed  Year  \
# 0          0.0       29.140    29.820         2.20       26.0      9.40  2007
# 1          0.0       29.410    30.085        13.15        3.0     13.40  2007
# 2          0.0       29.425    30.120        12.30        6.5     12.55  2007
# 3          0.0       29.335    30.045        10.25        7.5     10.60  2007
# 4          0.0       29.430    30.095        11.45        7.0     11.75  2007
#
#    Month  YearWeek  YearMonth
# 0      5    200718      20075
# 1      5    200718      20075
# 2      5    200718      20075
# 3      5    200718      20075
# 4      5    200718      20075

# %%
weather.isna().any().sum()
# Out:
# 0

# %%
train.head()
# Out:
#         Date                 Species   Latitude  Longitude  NumMosquitos  \
# 0 2007-05-29  CULEX PIPIENS/RESTUANS  41.954690 -87.800991             1
# 1 2007-05-29          CULEX RESTUANS  41.954690 -87.800991             1
# 2 2007-05-29          CULEX RESTUANS  41.994991 -87.769279             1
# 3 2007-05-29  CULEX PIPIENS/RESTUANS  41.974089 -87.824812             1
# 4 2007-05-29          CULEX RESTUANS  41.974089 -87.824812             4
#
#    WnvPresent
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
train.isna().any().sum()
# Out:
# 0

# %% [markdown]
# # Weather & Train Data Sets - EDA and Feature Engineering

# %% [markdown]
# According to the researches, if the weather gets too hot and too dry, mosquitoes will not be as active and feeding as they usually are. But once the humidity increases they’re more hungry and biting more.Therefore humidity plays a key role in WVN Presence. We will add the relative humidity as a feature.

# %%
# calculation of RELATIVE HUMIDITY
def rel_humidity(df,T, Td,Tw):
    
# Convert the air temperature and dew-point temperature to Celsius.(C=5*(F-32)/9)
    Tc= (5.0*(df[T]-32))/9.0
    Tdc= (5.0*(df[Td]-32))/9.0

#Calculate the saturated vapor pressure with a formula.  
    es=6.11*10.0**(7.5*Tc/(237.7+Tc))

#Find the actual vapor pressure with the same formula.
    e=6.11*10.0**(7.5*Tdc/(237.7+Tdc))
    
#Calculate the relative humidity.    
    df['RelHumidity']= round((e/es)*100)
    return df

# %%
rel_humidity(weather,'Tavg','DewPoint', 'WetBulb')
# Out:
#            Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  Cool  \
# 0    2007-05-01    83    51    67    14.0      51.0     56.5   0.0   2.5
# 1    2007-05-02    59    42    51    -3.0      42.0     47.0  13.5   0.0
# 2    2007-05-03    66    47    57     2.0      40.0     49.0   8.0   0.0
# 3    2007-05-04    72    50    61     4.0      41.5     50.0   4.0   0.0
# 4    2007-05-05    66    53    60     5.0      38.5     49.5   5.0   0.0
# ...         ...   ...   ...   ...     ...       ...      ...   ...   ...
# 1467 2014-10-27    78    52    65    16.0      51.5     58.5   0.5   1.0
# 1468 2014-10-28    67    46    57    10.0      39.0     47.5   8.0   0.0
# 1469 2014-10-29    49    38    44    -4.0      33.0     41.0  21.0   0.0
# 1470 2014-10-30    52    34    43    -4.0      34.5     41.0  21.5   0.0
# 1471 2014-10-31    48    33    41    -6.0      27.0     34.5  24.0   0.0
#
#       PrecipTotal  StnPressure  SeaLevel  ResultSpeed  ResultDir  AvgSpeed  \
# 0           0.000       29.140    29.820         2.20       26.0      9.40
# 1           0.000       29.410    30.085        13.15        3.0     13.40
# 2           0.000       29.425    30.120        12.30        6.5     12.55
# 3           0.000       29.335    30.045        10.25        7.5     10.60
# 4           0.000       29.430    30.095        11.45        7.0     11.75
# ...           ...          ...       ...          ...        ...       ...
# 1467        0.010       28.960    29.665        12.35       19.0     13.25
# 1468        0.025       29.190    29.850        14.40       26.0     15.10
# 1469        0.000       29.390    30.065         9.00       29.0      9.45
# 1470        0.000       29.375    30.095         5.50       23.5      6.00
# 1471        0.035       29.515    30.200        22.15       34.0     22.75
#
#       Year  Month  YearWeek  YearMonth  RelHumidity
# 0     2007      5    200718      20075         56.0
# 1     2007      5    200718      20075         71.0
# 2     2007      5    200718      20075         53.0
# 3     2007      5    200718      20075         49.0
# 4     2007      5    200718      20075         45.0
# ...    ...    ...       ...        ...          ...
# 1467  2014     10    201444     201410         62.0
# 1468  2014     10    201444     201410         51.0
# 1469  2014     10    201444     201410         65.0
# 1470  2014     10    201444     201410         72.0
# 1471  2014     10    201444     201410         57.0
#
# [1472 rows x 20 columns]

# %% [markdown]
# I will calculate time lags by giving higher weights to the most recent observed values.

# %%
def ema(df,col, span):
    df[f'{col}_{span}']= round(df[col].ewm(span=span, adjust=True).mean(),2)
    return df.dropna()
ema_list= ['Tmax', 'DewPoint','WetBulb','PrecipTotal', 'StnPressure','SeaLevel', 'ResultSpeed', 'ResultDir', 'AvgSpeed','RelHumidity']
span= list(range(1,15))
for i in ema_list:
    for s in span:
        ema(weather,i,s)

# %%
weather.head()
# Out:
#         Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  Cool  \
# 0 2007-05-01    83    51    67    14.0      51.0     56.5   0.0   2.5
# 1 2007-05-02    59    42    51    -3.0      42.0     47.0  13.5   0.0
# 2 2007-05-03    66    47    57     2.0      40.0     49.0   8.0   0.0
# 3 2007-05-04    72    50    61     4.0      41.5     50.0   4.0   0.0
# 4 2007-05-05    66    53    60     5.0      38.5     49.5   5.0   0.0
#
#    PrecipTotal  ...  RelHumidity_5  RelHumidity_6  RelHumidity_7  \
# 0          0.0  ...          56.00          56.00          56.00
# 1          0.0  ...          65.00          64.75          64.57
# 2          0.0  ...          59.32          59.47          59.57
# 3          0.0  ...          55.03          55.42          55.70
# 4          0.0  ...          51.18          51.77          52.19
#
#    RelHumidity_8  RelHumidity_9  RelHumidity_10  RelHumidity_11  \
# 0          56.00          56.00           56.00           56.00
# 1          64.44          64.33           64.25           64.18
# 2          59.64          59.69           59.73           59.76
# 3          55.91          56.07           56.19           56.30
# 4          52.52          52.78           52.98           53.15
#
#    RelHumidity_12  RelHumidity_13  RelHumidity_14
# 0           56.00           56.00           56.00
# 1           64.12           64.08           64.04
# 2           59.78           59.80           59.82
# 3           56.38           56.45           56.51
# 4           53.29           53.41           53.51
#
# [5 rows x 160 columns]

# %%
weather.isna().any().sum()
# Out:
# 0

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Columns: 160 entries, Date to RelHumidity_14
# dtypes: datetime64[ns](1), float64(152), int64(7)
# memory usage: 1.8 MB

# %%
w_train= train.merge(weather, on= ['Date'])
w_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9693 entries, 0 to 9692
# Columns: 165 entries, Date to RelHumidity_14
# dtypes: datetime64[ns](1), float64(154), int64(9), object(1)
# memory usage: 12.3+ MB

# %% [markdown]
# **The below chart indicates CULEX RESTUANS species were most affected by temperature increases.**

# %%
w_train=pd.get_dummies(w_train,drop_first=True)
#w_train=pd.get_dummies(w_train)
w_train.head()
# Out:
#         Date   Latitude  Longitude  NumMosquitos  WnvPresent  Tmax  Tmin  \
# 0 2007-05-29  41.954690 -87.800991             1           0    88    62
# 1 2007-05-29  41.954690 -87.800991             1           0    88    62
# 2 2007-05-29  41.994991 -87.769279             1           0    88    62
# 3 2007-05-29  41.974089 -87.824812             1           0    88    62
# 4 2007-05-29  41.974089 -87.824812             4           0    88    62
#
#    Tavg  Depart  DewPoint  ...  RelHumidity_11  RelHumidity_12  \
# 0    75    10.0      58.5  ...           54.88           54.61
# 1    75    10.0      58.5  ...           54.88           54.61
# 2    75    10.0      58.5  ...           54.88           54.61
# 3    75    10.0      58.5  ...           54.88           54.61
# 4    75    10.0      58.5  ...           54.88           54.61
#
#    RelHumidity_13  RelHumidity_14  Species_CULEX PIPIENS  \
# 0           54.37           54.16                      0
# 1           54.37           54.16                      0
# 2           54.37           54.16                      0
# 3           54.37           54.16                      0
# 4           54.37           54.16                      0
#
#    Species_CULEX PIPIENS/RESTUANS  Species_CULEX RESTUANS  \
# 0                               1                       0
# 1                               0                       1
# 2                               0                       1
# 3                               1                       0
# 4                               0                       1
#
#    Species_CULEX SALINARIUS  Species_CULEX TARSALIS  Species_CULEX TERRITANS
# 0                         0                       0                        0
# 1                         0                       0                        0
# 2                         0                       0                        0
# 3                         0                       0                        0
# 4                         0                       0                        0
#
# [5 rows x 170 columns]

# %%
w_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9693 entries, 0 to 9692
# Columns: 170 entries, Date to Species_CULEX TERRITANS
# dtypes: datetime64[ns](1), float64(154), int64(9), uint8(6)
# memory usage: 12.3 MB

# %%
w_train.isna().any().sum()
# Out:
# 0

# %%
print('\n','The Percantage of Virus per Each Species  ','\n')
print('CULEX PIPIENS: ', round(w_train[w_train.WnvPresent==1]['Species_CULEX PIPIENS'].sum()/len(w_train[w_train.WnvPresent==1]['Species_CULEX PIPIENS'])*100,2))
print('CULEX RESTUANS: ', round(w_train[w_train.WnvPresent==1]['Species_CULEX RESTUANS'].sum()/len(w_train[w_train.WnvPresent==1]['Species_CULEX RESTUANS'])*100,2))
print('CULEX PIPIENS/RESTUANS: ', round(w_train[w_train.WnvPresent==1]['Species_CULEX PIPIENS/RESTUANS'].sum()/len(w_train[w_train.WnvPresent==1]['Species_CULEX PIPIENS/RESTUANS'])*100),2)
# Out:
#  The Percantage of Virus per Each Species
#
# CULEX PIPIENS:  41.35
# CULEX RESTUANS:  9.74
# CULEX PIPIENS/RESTUANS:  49.0 2

# %% [markdown]
# **The below Correlation report indicates Relative Humidity is highly correlated with WN Virus, consequently Dew Temperature and Wet Bulb. Also their 7 and 14 days Exponential Mean Averages have higher correlation than the actual observation values. This must be because of the incubation period.**

# %% [markdown]
# figure = plt.figure(figsize=(10,40))
# sns.heatmap(w_train.corr()[['WnvPresent']].sort_values('WnvPresent',ascending=False),annot=True, cmap='YlGnBu')

# %% [markdown]
# **We will check if there is multicollinearity among the features and fix them.**

# %%
X = w_train.drop('WnvPresent', axis=1)
y = w_train['WnvPresent']
X_train,X_test, y_train,y_test = train_test_split(X, y,test_size=0.3)
print(X_train.shape, y_train.shape)
print(len(X_train.columns[X_train.isna().any()]))
# Out:
# (6785, 169) (6785,)
# 0

# %% [markdown]
# Weight of Evidence (WOE) helps to transform a continuous independent variable into a set of groups or bins based on similarity of dependent variable distribution i.e. number of events and non-events.
# Informtion of Evidence (IV) helps to rank variables on the basis of their importance. It measures predictive power of independent variables

# %% [markdown]
# Information value is not an optimal feature (variable) selection method when you are building a classification model other than binary logistic regression (for eg. random forest or SVM) as conditional log odds (which we predict in a logistic regression model) is highly related to the calculation of weight of evidence. In other words, it's designed mainly for binary logistic regression model. Also think this way - Random forest can detect non-linear relationship very well so selecting variables via Information Value and using them in random forest model might not produce the most accurate and robust predictive model.

# %%
pd.options.mode.use_inf_as_na = True
max_bin = 20
force_bin = 3

# define a binning function
def mono_bin(Y, X, n = max_bin):
    
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]
    r = 0
    while np.abs(r) < 1:
        try:
            d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.qcut(notmiss.X, n)})
            d2 = d1.groupby('Bucket', as_index=True)
            r, p = stats.spearmanr(d2.mean().X, d2.mean().Y)
            n = n - 1 
        except Exception as e:
            n = n - 1

    if len(d2) == 1:
        n = force_bin         
        bins = algos.quantile(notmiss.X, np.linspace(0, 1, n))
        if len(np.unique(bins)) == 2:
            bins = np.insert(bins, 0, 1)
            bins[1] = bins[1]-(bins[1]/2)
        d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.cut(notmiss.X, np.unique(bins),include_lowest=True)}) 
        d2 = d1.groupby('Bucket', as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["MIN_VALUE"] = d2.min().X
    d3["MAX_VALUE"] = d2.max().X
    d3["COUNT"] = d2.count().Y
    d3["EVENT"] = d2.sum().Y
    d3["NONEVENT"] = d2.count().Y - d2.sum().Y
    d3=d3.reset_index(drop=True)
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]       
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    
    return(d3)

def char_bin(Y, X):
        
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]    
    df2 = notmiss.groupby('X',as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["COUNT"] = df2.count().Y
    d3["MIN_VALUE"] = df2.sum().Y.index
    d3["MAX_VALUE"] = d3["MIN_VALUE"]
    d3["EVENT"] = df2.sum().Y
    d3["NONEVENT"] = df2.count().Y - df2.sum().Y
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]      
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    d3 = d3.reset_index(drop=True)
    
    return(d3)

def data_vars(df1, target):
    
    stack = traceback.extract_stack()
    filename, lineno, function_name, code = stack[-2]
    vars_name = re.compile(r'\((.*?)\).*$').search(code).groups()[0]
    final = (re.findall(r"[\w']+", vars_name))[-1]
    
    x = df1.dtypes.index
    count = -1
    
    for i in x:
        if i.upper() not in (final.upper()):
            if np.issubdtype(df1[i], np.number) and len(Series.unique(df1[i])) > 2:
                conv = mono_bin(target, df1[i])
                conv["VAR_NAME"] = i
                count = count + 1
            else:
                conv = char_bin(target, df1[i])
                conv["VAR_NAME"] = i            
                count = count + 1
                
            if count == 0:
                iv_df = conv
            else:
                iv_df = iv_df.append(conv,ignore_index=True)
    
    iv = pd.DataFrame({'IV':iv_df.groupby('VAR_NAME').IV.max()})
    iv = iv.reset_index()
    return(iv_df,iv)

# %%
final_iv, IV = data_vars(X_train, y_train)
# Out:
# C:\Users\laptop\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
final_iv.head()
# Out:
#   VAR_NAME            MIN_VALUE            MAX_VALUE  COUNT  EVENT  \
# 0     Date  2007-05-29 00:00:00  2007-05-29 00:00:00     15      0
# 1     Date  2007-06-05 00:00:00  2007-06-05 00:00:00     34      0
# 2     Date  2007-06-26 00:00:00  2007-06-26 00:00:00     52      0
# 3     Date  2007-06-29 00:00:00  2007-06-29 00:00:00     34      0
# 4     Date  2007-07-02 00:00:00  2007-07-02 00:00:00     53      0
#
#    EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  WOE  \
# 0         0.0        15             1.0         0.0        0.002337  0.0
# 1         0.0        34             1.0         0.0        0.005298  0.0
# 2         0.0        52             1.0         0.0        0.008102  0.0
# 3         0.0        34             1.0         0.0        0.005298  0.0
# 4         0.0        53             1.0         0.0        0.008258  0.0
#
#          IV
# 0  0.929161
# 1  0.929161
# 2  0.929161
# 3  0.929161
# 4  0.929161

# %%
final_iv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   VAR_NAME        542 non-null    object
#  1   MIN_VALUE       542 non-null    object
#  2   MAX_VALUE       542 non-null    object
#  3   COUNT           542 non-null    int64
#  4   EVENT           542 non-null    int64
#  5   EVENT_RATE      542 non-null    float64
#  6   NONEVENT        542 non-null    int64
#  7   NON_EVENT_RATE  542 non-null    float64
#  8   DIST_EVENT      542 non-null    float64
#  9   DIST_NON_EVENT  542 non-null    float64
#  10  WOE             542 non-null    float64
#  11  IV              542 non-null    float64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 50.9+ KB

# %%
final_iv.isna().any().sum()
# Out:
# 0

# %%
IV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   VAR_NAME  169 non-null    object
#  1   IV        169 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.8+ KB

# %%
IV.isna().any().sum()
# Out:
# 0

# %%
features = list(IV[(IV['IV'] >= 0.1) & (IV['IV'] <= 0.8)]['VAR_NAME'])
X2 = X_train[features]
X2.head()
# Out:
#       AvgSpeed_13  DewPoint  DewPoint_1  DewPoint_10  DewPoint_11  \
# 7987         7.71      53.5        53.5        60.86        60.92
# 7078         8.58      59.0        59.0        57.29        57.33
# 2066         6.92      70.5        70.5        65.45        65.32
# 6592         6.94      58.0        58.0        61.84        62.24
# 6193         7.37      66.5        66.5        68.24        68.02
#
#       DewPoint_12  DewPoint_13  DewPoint_14  DewPoint_2  DewPoint_3  ...  \
# 7987        60.95        60.95        60.93       54.91       56.89  ...
# 7078        57.38        57.45        57.53       58.98       58.65  ...
# 2066        65.21        65.12        65.03       69.85       68.77  ...
# 6592        62.58        62.88        63.13       57.01       57.31  ...
# 6193        67.78        67.54        67.31       67.58       68.22  ...
#
#       WetBulb_14  WetBulb_2  WetBulb_3  WetBulb_4  WetBulb_5  WetBulb_6  \
# 7987       66.03      62.55      63.92      64.89      65.49      65.85
# 7078       62.50      64.33      63.67      63.09      62.68      62.42
# 2066       68.32      72.13      71.03      70.14      69.51      69.09
# 6592       67.79      63.24      63.41      63.90      64.46      65.00
# 6193       71.91      71.61      72.11      72.49      72.72      72.82
#
#       WetBulb_7  WetBulb_8  WetBulb_9  Year
# 7987      66.05      66.15      66.19  2013
# 7078      62.27      62.21      62.20  2011
# 2066      68.81      68.64      68.52  2007
# 6592      65.51      65.96      66.37  2011
# 6193      72.83      72.78      72.68  2011
#
# [5 rows x 59 columns]

# %%
X2.isna().any().sum()
# Out:
# 0

# %%
X2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6785 entries, 7987 to 3870
# Data columns (total 59 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   AvgSpeed_13             6785 non-null   float64
#  1   DewPoint                6785 non-null   float64
#  2   DewPoint_1              6785 non-null   float64
#  3   DewPoint_10             6785 non-null   float64
#  4   DewPoint_11             6785 non-null   float64
#  5   DewPoint_12             6785 non-null   float64
#  6   DewPoint_13             6785 non-null   float64
#  7   DewPoint_14             6785 non-null   float64
#  8   DewPoint_2              6785 non-null   float64
#  9   DewPoint_3              6785 non-null   float64
#  10  DewPoint_4              6785 non-null   float64
#  11  DewPoint_5              6785 non-null   float64
#  12  DewPoint_6              6785 non-null   float64
#  13  DewPoint_7              6785 non-null   float64
#  14  DewPoint_8              6785 non-null   float64
#  15  DewPoint_9              6785 non-null   float64
#  16  Heat                    6785 non-null   float64
#  17  Longitude               6785 non-null   float64
#  18  PrecipTotal             6785 non-null   float64
#  19  PrecipTotal_1           6785 non-null   float64
#  20  RelHumidity_3           6785 non-null   float64
#  21  RelHumidity_4           6785 non-null   float64
#  22  RelHumidity_7           6785 non-null   float64
#  23  RelHumidity_8           6785 non-null   float64
#  24  RelHumidity_9           6785 non-null   float64
#  25  ResultSpeed_14          6785 non-null   float64
#  26  SeaLevel_12             6785 non-null   float64
#  27  SeaLevel_13             6785 non-null   float64
#  28  SeaLevel_14             6785 non-null   float64
#  29  Species_CULEX PIPIENS   6785 non-null   uint8
#  30  Species_CULEX RESTUANS  6785 non-null   uint8
#  31  StnPressure_10          6785 non-null   float64
#  32  StnPressure_12          6785 non-null   float64
#  33  StnPressure_13          6785 non-null   float64
#  34  StnPressure_14          6785 non-null   float64
#  35  StnPressure_6           6785 non-null   float64
#  36  StnPressure_8           6785 non-null   float64
#  37  StnPressure_9           6785 non-null   float64
#  38  Tmax_10                 6785 non-null   float64
#  39  Tmax_11                 6785 non-null   float64
#  40  Tmax_12                 6785 non-null   float64
#  41  Tmax_13                 6785 non-null   float64
#  42  Tmax_14                 6785 non-null   float64
#  43  Tmax_9                  6785 non-null   float64
#  44  Tmin                    6785 non-null   int64
#  45  WetBulb_10              6785 non-null   float64
#  46  WetBulb_11              6785 non-null   float64
#  47  WetBulb_12              6785 non-null   float64
#  48  WetBulb_13              6785 non-null   float64
#  49  WetBulb_14              6785 non-null   float64
#  50  WetBulb_2               6785 non-null   float64
#  51  WetBulb_3               6785 non-null   float64
#  52  WetBulb_4               6785 non-null   float64
#  53  WetBulb_5               6785 non-null   float64
#  54  WetBulb_6               6785 non-null   float64
#  55  WetBulb_7               6785 non-null   float64
#  56  WetBulb_8               6785 non-null   float64
#  57  WetBulb_9               6785 non-null   float64
#  58  Year                    6785 non-null   int64
# dtypes: float64(55), int64(2), uint8(2)
# memory usage: 3.0 MB

# %%
X1 = X2._get_numeric_data()

# %%
X1.isna().any().sum()
# Out:
# 0

# %%
def iterate_vif(df, vif_threshold=700, max_vif=705):
  count = 0
  while max_vif > vif_threshold:
    count += 1
    print("Iteration # "+str(count))
    vif = pd.DataFrame()
    vif["VIFactor"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    vif["features"] = df.columns
    
    if round((vif['VIFactor'].max()),1) > vif_threshold:
      print('Removing %s with VIF of %f' % (vif[vif['VIFactor'] == vif['VIFactor'].max()]['features'].values[0], round((vif['VIFactor'].max()),1)))
      df = df.drop(vif[vif['VIFactor'] == vif['VIFactor'].max()]['features'].values[0], axis=1)
      max_vif = round((vif['VIFactor'].max()),1)
    else:
        print('Complete')
        return df, round((vif.sort_values('VIFactor')),1)
X1 = X2._get_numeric_data()
final_df, final_vif = iterate_vif(X1)
# Out:
# Iteration # 1
# C:\Users\laptop\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Removing Tmax_10 with VIF of 2288431887.100000
# Iteration # 2
# Removing WetBulb_13 with VIF of 1602894445.300000
# Iteration # 3
# Removing WetBulb_8 with VIF of 1415541896.800000
# Iteration # 4
# Removing Tmax_13 with VIF of 1211927195.400000
# Iteration # 5
# Removing WetBulb_11 with VIF of 1207103413.200000
# Iteration # 6
# Removing Tmax_12 with VIF of 839603898.300000
# Iteration # 7
# Removing WetBulb_9 with VIF of 834329027.400000
# Iteration # 8
# Removing DewPoint_11 with VIF of 755438648.300000
# Iteration # 9
# Removing WetBulb_6 with VIF of 642779834.200000
# Iteration # 10
# Removing DewPoint_9 with VIF of 597876397.900000
# Iteration # 11
# Removing RelHumidity_8 with VIF of 571703157.500000
# Iteration # 12
# Removing DewPoint_12 with VIF of 491222208.500000
# Iteration # 13
# Removing WetBulb_12 with VIF of 486585577.800000
# Iteration # 14
# Removing DewPoint_6 with VIF of 449808385.200000
# Iteration # 15
# Removing WetBulb_4 with VIF of 406833461.000000
# Iteration # 16
# Removing DewPoint_7 with VIF of 381202202.100000
# Iteration # 17
# Removing DewPoint_13 with VIF of 326057867.500000
# Iteration # 18
# Removing StnPressure_13 with VIF of 289971980.300000
# Iteration # 19
# Removing DewPoint_4 with VIF of 257412844.500000
# Iteration # 20
# Removing WetBulb_7 with VIF of 214362274.900000
# Iteration # 21
# Removing StnPressure_12 with VIF of 198338569.800000
# Iteration # 22
# Removing SeaLevel_13 with VIF of 158086276.500000
# Iteration # 23
# Removing StnPressure_10 with VIF of 144593099.500000
# Iteration # 24
# Removing StnPressure_8 with VIF of 133431567.900000
# Iteration # 25
# Removing SeaLevel_12 with VIF of 117680617.400000
# Iteration # 26
# Removing DewPoint_8 with VIF of 76000657.700000
# Iteration # 27
# Removing SeaLevel_14 with VIF of 67333369.100000
# Iteration # 28
# Removing StnPressure_9 with VIF of 55219024.700000
# Iteration # 29
# Removing Tmax_11 with VIF of 50853631.400000
# Iteration # 30
# Removing DewPoint_3 with VIF of 17528528.000000
# Iteration # 31
# Removing WetBulb_10 with VIF of 6186853.700000
# Iteration # 32
# Removing RelHumidity_7 with VIF of 3747081.200000
# Iteration # 33
# Removing WetBulb_3 with VIF of 3342820.800000
# Iteration # 34
# Removing StnPressure_14 with VIF of 2279907.700000
# Iteration # 35
# Removing Year with VIF of 620429.700000
# Iteration # 36
# Removing DewPoint_10 with VIF of 307102.600000
# Iteration # 37
# Removing Tmax_14 with VIF of 253769.600000
# Iteration # 38
# Removing Longitude with VIF of 169284.900000
# Iteration # 39
# Removing RelHumidity_4 with VIF of 85412.800000
# Iteration # 40
# Removing PrecipTotal with VIF of 54570.700000
# Iteration # 41
# Removing DewPoint_5 with VIF of 46188.700000
# Iteration # 42
# Removing WetBulb_5 with VIF of 23784.400000
# Iteration # 43
# Removing Tmax_9 with VIF of 10316.500000
# Iteration # 44
# Removing WetBulb_14 with VIF of 4288.600000
# Iteration # 45
# Removing DewPoint_2 with VIF of 3769.100000
# Iteration # 46
# Removing RelHumidity_9 with VIF of 1307.200000
# Iteration # 47
# Removing WetBulb_2 with VIF of 825.300000
# Iteration # 48
# Removing Tmin with VIF of 757.200000
# Iteration # 49
# Complete

# %%
X_train=final_df
X_train.head()
# Out:
#       AvgSpeed_13  DewPoint  DewPoint_1  DewPoint_14  Heat  PrecipTotal_1  \
# 7987         7.71      53.5        53.5        60.93   0.0           0.00
# 7078         8.58      59.0        59.0        57.53   0.0           0.00
# 2066         6.92      70.5        70.5        65.03   0.0           0.62
# 6592         6.94      58.0        58.0        63.13   0.0           0.00
# 6193         7.37      66.5        66.5        67.31   0.0           0.00
#
#       RelHumidity_3  ResultSpeed_14  Species_CULEX PIPIENS  \
# 7987          58.02            6.61                      0
# 7078          63.94            7.54                      0
# 2066          77.36            4.43                      0
# 6592          61.02            5.41                      0
# 6193          65.67            4.49                      0
#
#       Species_CULEX RESTUANS  StnPressure_6
# 7987                       1          29.33
# 7078                       1          29.29
# 2066                       0          29.27
# 6592                       1          29.19
# 6193                       0          29.23

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6785 entries, 7987 to 3870
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   AvgSpeed_13             6785 non-null   float64
#  1   DewPoint                6785 non-null   float64
#  2   DewPoint_1              6785 non-null   float64
#  3   DewPoint_14             6785 non-null   float64
#  4   Heat                    6785 non-null   float64
#  5   PrecipTotal_1           6785 non-null   float64
#  6   RelHumidity_3           6785 non-null   float64
#  7   ResultSpeed_14          6785 non-null   float64
#  8   Species_CULEX PIPIENS   6785 non-null   uint8
#  9   Species_CULEX RESTUANS  6785 non-null   uint8
#  10  StnPressure_6           6785 non-null   float64
# dtypes: float64(9), uint8(2)
# memory usage: 543.3 KB

# %%
X_train.isna().any().sum()
# Out:
# 0

# %%
final_vif
# Out:
#     VIFactor                features
# 8        1.5   Species_CULEX PIPIENS
# 9        1.6  Species_CULEX RESTUANS
# 5        2.0           PrecipTotal_1
# 4        2.5                    Heat
# 6      139.1           RelHumidity_3
# 7      237.6          ResultSpeed_14
# 3      369.5             DewPoint_14
# 0      436.6             AvgSpeed_13
# 10     452.6           StnPressure_6
# 1        NaN                DewPoint
# 2        NaN              DewPoint_1

# %%
final_vif.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 3 to 1
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   VIFactor  5 non-null      float64
#  1   features  7 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 168.0+ bytes
